# %%
packages = ['anomalib', 'lightning', 'kornia', 'FrEIA', 'python_dotenv', 'open_clip_torch']

# %%
%%writefile dependencies.txt
anomalib
lightning
kornia
FrEIA
python-dotenv
open_clip_torch
qdrant-client
typing-extensions
pydantic
# Out:
# Writing dependencies.txt

# %%
!pip install -r dependencies.txt
# Out:
# Collecting anomalib (from -r dependencies.txt (line 1))
#   Downloading anomalib-1.2.0-py3-none-any.whl.metadata (27 kB)
# Collecting lightning (from -r dependencies.txt (line 2))
#   Downloading lightning-2.4.0-py3-none-any.whl.metadata (38 kB)
# Collecting kornia (from -r dependencies.txt (line 3))
#   Downloading kornia-0.7.3-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting FrEIA (from -r dependencies.txt (line 4))
#   Downloading FrEIA-0.2.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-dotenv (from -r dependencies.txt (line 5))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting open_clip_torch (from -r dependencies.txt (line 6))
#   Downloading open_clip_torch-2.29.0-py3-none-any.whl.metadata (31 kB)
# Collecting qdrant-client (from -r dependencies.txt (line 7))
#   Downloading qdrant_client-1.12.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from -r dependencies.txt (line 8)) (4.12.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from -r dependencies.txt (line 9)) (2.9.2)
# Collecting omegaconf>=2.1.1 (from anomalib->-r dependencies.txt (line 1))
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: rich>=13.5.2 in /usr/local/lib/python3.10/dist-packages (from anomalib->-r dependencies.txt (line 1)) (13.9.3)
# Collecting jsonargparse>=4.27.7 (from jsonargparse[signatures]>=4.27.7->anomalib->-r dependencies.txt (line 1))
#   Downloading jsonargparse-4.33.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.10/dist-packages (from anomalib->-r dependencies.txt (line 1)) (0.16)
# Collecting rich-argparse (from anomalib->-r dependencies.txt (line 1))
#   Downloading rich_argparse-1.6.0-py3-none-any.whl.metadata (14 kB)
# Collecting lightning-utilities (from anomalib->-r dependencies.txt (line 1))
#   Downloading lightning_utilities-0.11.8-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.10/dist-packages (from lightning->-r dependencies.txt (line 2)) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning->-r dependencies.txt (line 2)) (2024.10.0)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r dependencies.txt (line 2)) (24.1)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r dependencies.txt (line 2)) (2.5.0+cu121)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning->-r dependencies.txt (line 2))
#   Downloading torchmetrics-1.5.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from lightning->-r dependencies.txt (line 2)) (4.66.6)
# Collecting pytorch-lightning (from lightning->-r dependencies.txt (line 2))
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting kornia-rs>=0.1.0 (from kornia->-r dependencies.txt (line 3))
#   Downloading kornia_rs-0.1.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from FrEIA->-r dependencies.txt (line 4)) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from FrEIA->-r dependencies.txt (line 4)) (1.13.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from open_clip_torch->-r dependencies.txt (line 6)) (0.20.0+cu121)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from open_clip_torch->-r dependencies.txt (line 6)) (2024.9.11)
# Collecting ftfy (from open_clip_torch->-r dependencies.txt (line 6))
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from open_clip_torch->-r dependencies.txt (line 6)) (0.24.7)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from open_clip_torch->-r dependencies.txt (line 6)) (0.4.5)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from open_clip_torch->-r dependencies.txt (line 6)) (1.0.11)
# Requirement already satisfied: grpcio>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client->-r dependencies.txt (line 7)) (1.64.1)
# Collecting grpcio-tools>=1.41.0 (from qdrant-client->-r dependencies.txt (line 7))
#   Downloading grpcio_tools-1.67.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: httpx>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client->-r dependencies.txt (line 7)) (0.27.2)
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant-client->-r dependencies.txt (line 7))
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /usr/local/lib/python3.10/dist-packages (from qdrant-client->-r dependencies.txt (line 7)) (2.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->-r dependencies.txt (line 9)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->-r dependencies.txt (line 9)) (2.23.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning->-r dependencies.txt (line 2)) (3.10.10)
# Collecting protobuf<6.0dev,>=5.26.1 (from grpcio-tools>=1.41.0->qdrant-client->-r dependencies.txt (line 7))
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting grpcio>=1.41.0 (from qdrant-client->-r dependencies.txt (line 7))
#   Downloading grpcio-1.67.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.41.0->qdrant-client->-r dependencies.txt (line 7)) (75.1.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r dependencies.txt (line 7)) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r dependencies.txt (line 7)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r dependencies.txt (line 7)) (1.0.6)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r dependencies.txt (line 7)) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r dependencies.txt (line 7)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r dependencies.txt (line 7)) (0.14.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.20.0->qdrant-client->-r dependencies.txt (line 7))
#   Downloading h2-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting typeshed-client>=2.1.0 (from jsonargparse[signatures]>=4.27.7->anomalib->-r dependencies.txt (line 1))
#   Downloading typeshed_client-2.7.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.1.1->anomalib->-r dependencies.txt (line 1))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.5.2->anomalib->-r dependencies.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.5.2->anomalib->-r dependencies.txt (line 1)) (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.1.0->lightning->-r dependencies.txt (line 2)) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.1.0->lightning->-r dependencies.txt (line 2)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.1.0->lightning->-r dependencies.txt (line 2)) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.1.0->lightning->-r dependencies.txt (line 2)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch<4.0,>=2.1.0->lightning->-r dependencies.txt (line 2)) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy->open_clip_torch->-r dependencies.txt (line 6)) (0.2.13)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->open_clip_torch->-r dependencies.txt (line 6)) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->open_clip_torch->-r dependencies.txt (line 6)) (10.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->-r dependencies.txt (line 2)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->-r dependencies.txt (line 2)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->-r dependencies.txt (line 2)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->-r dependencies.txt (line 2)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->-r dependencies.txt (line 2)) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->-r dependencies.txt (line 2)) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->-r dependencies.txt (line 2)) (4.0.3)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client->-r dependencies.txt (line 7))
#   Downloading hyperframe-6.0.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client->-r dependencies.txt (line 7))
#   Downloading hpack-4.0.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.5.2->anomalib->-r dependencies.txt (line 1)) (0.1.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from typeshed-client>=2.1.0->jsonargparse[signatures]>=4.27.7->anomalib->-r dependencies.txt (line 1)) (6.4.5)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client->-r dependencies.txt (line 7)) (1.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<4.0,>=2.1.0->lightning->-r dependencies.txt (line 2)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->open_clip_torch->-r dependencies.txt (line 6)) (3.4.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->-r dependencies.txt (line 2)) (0.2.0)
# Downloading anomalib-1.2.0-py3-none-any.whl (486 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.6/486.6 kB 22.5 MB/s eta 0:00:00
# Downloading lightning-2.4.0-py3-none-any.whl (810 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 40.3 MB/s eta 0:00:00
# Downloading kornia-0.7.3-py2.py3-none-any.whl (833 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 833.3/833.3 kB 59.4 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading open_clip_torch-2.29.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 73.8 MB/s eta 0:00:00
# Downloading qdrant_client-1.12.1-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.2/267.2 kB 27.3 MB/s eta 0:00:00
# Downloading grpcio_tools-1.67.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 87.6 MB/s eta 0:00:00
# Downloading grpcio-1.67.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 106.2 MB/s eta 0:00:00
# Downloading jsonargparse-4.33.2-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 19.9 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.3 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.8-py3-none-any.whl (26 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.8 MB/s eta 0:00:00
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading torchmetrics-1.5.1-py3-none-any.whl (890 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.6/890.6 kB 57.3 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.5 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 54.0 MB/s eta 0:00:00
# Downloading rich_argparse-1.6.0-py3-none-any.whl (20 kB)
# Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.6 MB/s eta 0:00:00
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 30.4 MB/s eta 0:00:00
# Downloading typeshed_client-2.7.0-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 kB 44.6 MB/s eta 0:00:00
# Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Building wheels for collected packages: FrEIA, antlr4-python3-runtime
#   Building wheel for FrEIA (setup.py) ... done
#   Created wheel for FrEIA: filename=FrEIA-0.2-py3-none-any.whl size=42762 sha256=6838dbaf0187a9b36b8ecb4f75967b2065a2a2ae5600b7d52a2cb13163ef1f06
#   Stored in directory: /root/.cache/pip/wheels/81/a8/e2/d532a76f72108ac4a340cbe3f86b4f591abfdbd75209a5badb
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=affcb9b50e886f7d1f26e095cb2c4c96dda796e121f56bb770bdf64afe68fbb1
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built FrEIA antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, typeshed-client, python-dotenv, protobuf, portalocker, omegaconf, lightning-utilities, kornia-rs, jsonargparse, hyperframe, hpack, grpcio, ftfy, h2, grpcio-tools, torchmetrics, rich-argparse, kornia, FrEIA, qdrant-client, anomalib, pytorch-lightning, open_clip_torch, lightning
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.64.1
#     Uninstalling grpcio-1.64.1:
#       Successfully uninstalled grpcio-1.64.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-datastore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.3 which is incompatible.
# google-cloud-firestore 2.16.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.28.3 which is incompatible.
# tensorboard 2.17.0 requires protobuf!=4.24.0,<5.0.0,>=3.19.6, but you have protobuf 5.28.3 which is incompatible.
# tensorflow 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.28.3 which is incompatible.
# Successfully installed FrEIA-0.2 anomalib-1.2.0 antlr4-python3-runtime-4.9.3 ftfy-6.3.1 grpcio-1.67.1 grpcio-tools-1.67.1 h2-4.1.0 hpack-4.0.0 hyperframe-6.0.1 jsonargparse-4.33.2 kornia-0.7.3 kornia-rs-0.1.7 lightning-2.4.0 lightning-utilities-0.11.8 omegaconf-2.3.0 open_clip_torch-2.29.0 portalocker-2.10.1 protobuf-5.28.3 python-dotenv-1.0.1 pytorch-lightning-2.4.0 qdrant-client-1.12.1 rich-argparse-1.6.0 torchmetrics-1.5.1 typeshed-client-2.7.0

# %%
from anomalib.data import MVTec
from anomalib.models import EfficientAd, Patchcore
from anomalib.engine import Engine
from torch.utils.data import DataLoader
# Out:
# /usr/local/lib/python3.10/dist-packages/kornia/feature/lightglue.py:44: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @torch.cuda.amp.custom_fwd(cast_inputs=torch.float32)

# %% [markdown]
# # *Visualisation function*

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

%matplotlib inline

def visualize_results(image, anomaly_map, pred_label=None, pred_score=None):

    plt.figure(figsize=(12, 8))

    # Original image
    plt.subplot(131)
    plt.imshow(image)
    plt.title('Original Image')
    plt.axis('on')

    # Anomaly map
    plt.subplot(132)
    plt.imshow(anomaly_map, cmap='jet')
    plt.title('Anomaly Map')
    plt.colorbar(fraction=0.046, pad=0.04)
    plt.axis('on')

    # Overlay
    plt.subplot(133)
    plt.imshow(image)
    plt.imshow(anomaly_map, cmap='jet', alpha=0.5)
    plt.title('Overlay')
    plt.axis('on')

    if pred_label is not None and pred_score is not None:
        plt.suptitle(f"Prediction: {'Anomaly' if pred_label else 'Normal'} (Score: {pred_score:.3f})")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # EfficientAd

# %%
# Initialize the model for each category

categories = ["tile", "grid", "leather"]
model_EfAd = {}
engine_EfAd={}
dataset_EfAd = {}
for category in categories:
    dataset_EfAd[category] = MVTec(root="path/to/mvtec", category=category, train_batch_size=1)
    model_EfAd[category] = EfficientAd()
    engine_EfAd[category] = Engine(max_epochs=1)

    # Train the model
    engine_EfAd[category].fit(datamodule=dataset_EfAd[category], model=model_EfAd[category])
# Out:
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# mvtec: 5.26GB [04:23, 20.0MB/s]
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# INFO:
#   | Name                  | Type                     | Params | Mode
# ---------------------------------------------------------------------------
# 0 | model                 | EfficientAdModel         | 8.1 M  | train
# 1 | _transform            | Compose                  | 0      | train
# 2 | normalization_metrics | MetricCollection         | 0      | train
# 3 | image_threshold       | F1AdaptiveThreshold      | 0      | train
# 4 | pixel_threshold       | F1AdaptiveThreshold      | 0      | train
# 5 | image_metrics         | AnomalibMetricCollection | 0      | train
# 6 | pixel_metrics         | AnomalibMetricCollection | 0      | train
# ---------------------------------------------------------------------------
# 8.1 M     Trainable params
# 0         Non-trainable params
# 8.1 M     Total params
# 32.235    Total estimated model params size (MB)
# 46        Modules in train mode
# 7         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name                  | Type                     | Params | Mode
# ---------------------------------------------------------------------------
# 0 | model                 | EfficientAdModel         | 8.1 M  | train
# 1 | _transform            | Compose                  | 0      | train
# 2 | normalization_metrics | MetricCollection         | 0      | train
# 3 | image_threshold       | F1AdaptiveThreshold      | 0      | train
# 4 | pixel_threshold       | F1AdaptiveThreshold      | 0      | train
# 5 | image_metrics         | AnomalibMetricCollection | 0      | train
# 6 | pixel_metrics         | AnomalibMetricCollection | 0      | train
# ---------------------------------------------------------------------------
# 8.1 M     Trainable params
# 0         Non-trainable params
# 8.1 M     Total params
# 32.235    Total estimated model params size (MB)
# 46        Modules in train mode
# 7         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# efficientad_pretrained_weights.zip: 0.00B [00:00, ?B/s]
# efficientad_pretrained_weights.zip:   0%|          | 8.19k/40.0M [00:00<51:53, 12.8kB/s]
# efficientad_pretrained_weights.zip:  26%|██▋       | 10.5M/40.0M [00:00<00:01, 18.4MB/s]
# efficientad_pretrained_weights.zip: 40.0MB [00:00, 41.5MB/s]
# /usr/local/lib/python3.10/dist-packages/anomalib/models/image/efficient_ad/lightning_model.py:98: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(
#
# imagenette2.tgz: 0.00B [00:00, ?B/s]
# imagenette2.tgz:   0%|          | 8.19k/1.56G [00:00<17:34:09, 24.6kB/s]
# imagenette2.tgz:   0%|          | 57.3k/1.56G [00:00<2:53:08, 150kB/s]
# imagenette2.tgz:   0%|          | 262k/1.56G [00:00<41:37, 623kB/s]
# imagenette2.tgz:   0%|          | 1.11M/1.56G [00:00<10:19, 2.51MB/s]
# imagenette2.tgz:   0%|          | 4.55M/1.56G [00:00<02:36, 9.93MB/s]
# imagenette2.tgz:   1%|          | 9.16M/1.56G [00:01<01:27, 17.6MB/s]
# imagenette2.tgz:   1%|          | 15.8M/1.56G [00:01<00:55, 27.6MB/s]
# imagenette2.tgz:   1%|▏         | 21.5M/1.56G [00:01<00:47, 32.0MB/s]
# imagenette2.tgz:   2%|▏         | 27.2M/1.56G [00:01<00:43, 35.3MB/s]
# imagenette2.tgz:   2%|▏         | 32.8M/1.56G [00:01<00:40, 37.4MB/s]
# imagenette2.tgz:   2%|▏         | 38.4M/1.56G [00:01<00:37, 40.7MB/s]
# imagenette2.tgz:   3%|▎         | 41.9M/1.56G [00:01<00:49, 30.7MB/s]
# imagenette2.tgz:   3%|▎         | 46.5M/1.56G [00:01<00:44, 34.0MB/s]
# imagenette2.tgz:   3%|▎         | 50.4M/1.56G [00:02<00:42, 35.2MB/s]
# imagenette2.tgz:   4%|▎         | 56.7M/1.56G [00:02<00:35, 41.9MB/s]
# imagenette2.tgz:   4%|▍         | 60.4M/1.56G [00:02<00:36, 40.6MB/s]
# imagenette2.tgz:   4%|▍         | 65.9M/1.56G [00:02<00:33, 44.5MB/s]
# imagenette2.tgz:   5%|▍         | 70.8M/1.56G [00:02<00:32, 45.1MB/s]
# imagenette2.tgz:   5%|▍         | 74.1M/1.56G [00:02<00:40, 36.6MB/s]
# imagenette2.tgz:   5%|▌         | 78.3M/1.56G [00:02<00:43, 34.4MB/s]
# imagenette2.tgz:   5%|▌         | 83.9M/1.56G [00:02<00:37, 39.7MB/s]
# imagenette2.tgz:   6%|▌         | 87.7M/1.56G [00:02<00:37, 39.4MB/s]
# imagenette2.tgz:   6%|▌         | 93.4M/1.56G [00:03<00:33, 44.1MB/s]
# imagenette2.tgz:   6%|▋         | 97.6M/1.56G [00:03<00:33, 43.5MB/s]
# imagenette2.tgz:   7%|▋         | 103M/1.56G [00:03<00:31, 45.9MB/s]
# imagenette2.tgz:   7%|▋         | 108M/1.56G [00:03<00:30, 47.2MB/s]
# imagenette2.tgz:   7%|▋         | 112M/1.56G [00:03<00:32, 45.1MB/s]
# imagenette2.tgz:   8%|▊         | 118M/1.56G [00:03<00:30, 47.9MB/s]
# imagenette2.tgz:   8%|▊         | 122M/1.56G [00:03<00:32, 44.6MB/s]
# imagenette2.tgz:   8%|▊         | 127M/1.56G [00:03<00:29, 48.3MB/s]
# imagenette2.tgz:   8%|▊         | 131M/1.56G [00:03<00:31, 45.0MB/s]
# imagenette2.tgz:   9%|▉         | 137M/1.56G [00:03<00:29, 49.0MB/s]
# imagenette2.tgz:   9%|▉         | 141M/1.56G [00:04<00:30, 45.9MB/s]
# imagenette2.tgz:   9%|▉         | 146M/1.56G [00:04<00:28, 48.9MB/s]
# imagenette2.tgz:  10%|▉         | 150M/1.56G [00:04<00:30, 45.7MB/s]
# imagenette2.tgz:  10%|█         | 156M/1.56G [00:04<00:28, 48.9MB/s]
# imagenette2.tgz:  10%|█         | 160M/1.56G [00:04<00:30, 45.9MB/s]
# imagenette2.tgz:  11%|█         | 166M/1.56G [00:04<00:28, 49.5MB/s]
# imagenette2.tgz:  11%|█         | 170M/1.56G [00:04<00:30, 45.9MB/s]
# imagenette2.tgz:  11%|█▏        | 177M/1.56G [00:04<00:28, 47.7MB/s]
# imagenette2.tgz:  12%|█▏        | 182M/1.56G [00:04<00:27, 49.2MB/s]
# imagenette2.tgz:  12%|█▏        | 186M/1.56G [00:05<00:29, 45.9MB/s]
# imagenette2.tgz:  12%|█▏        | 192M/1.56G [00:05<00:27, 49.6MB/s]
# imagenette2.tgz:  13%|█▎        | 196M/1.56G [00:05<00:29, 46.7MB/s]
# imagenette2.tgz:  13%|█▎        | 202M/1.56G [00:05<00:26, 50.8MB/s]
# imagenette2.tgz:  13%|█▎        | 206M/1.56G [00:05<00:28, 46.7MB/s]
# imagenette2.tgz:  14%|█▎        | 213M/1.56G [00:05<00:25, 52.3MB/s]
# imagenette2.tgz:  14%|█▍        | 217M/1.56G [00:05<00:27, 49.0MB/s]
# imagenette2.tgz:  14%|█▍        | 222M/1.56G [00:05<00:26, 50.8MB/s]
# imagenette2.tgz:  15%|█▍        | 227M/1.56G [00:05<00:27, 47.9MB/s]
# imagenette2.tgz:  15%|█▍        | 232M/1.56G [00:05<00:26, 50.6MB/s]
# imagenette2.tgz:  15%|█▌        | 236M/1.56G [00:06<00:28, 46.0MB/s]
# imagenette2.tgz:  94%|█████████▍| 1.47G/1.56G [00:33<00:01, 47.7MB/s]
# imagenette2.tgz:  95%|█████████▍| 1.48G/1.56G [00:33<00:01, 47.9MB/s]
# imagenette2.tgz:  95%|█████████▌| 1.48G/1.56G [00:34<00:01, 48.7MB/s]
# imagenette2.tgz:  96%|█████████▌| 1.49G/1.56G [00:34<00:01, 47.9MB/s]
# imagenette2.tgz:  96%|█████████▌| 1.50G/1.56G [00:34<00:01, 48.0MB/s]
# imagenette2.tgz:  96%|█████████▋| 1.50G/1.56G [00:34<00:01, 49.0MB/s]
# imagenette2.tgz:  97%|█████████▋| 1.51G/1.56G [00:34<00:01, 49.3MB/s]
# imagenette2.tgz:  97%|█████████▋| 1.51G/1.56G [00:34<00:00, 48.4MB/s]
# imagenette2.tgz:  97%|█████████▋| 1.52G/1.56G [00:34<00:00, 47.9MB/s]
# imagenette2.tgz:  98%|█████████▊| 1.52G/1.56G [00:34<00:00, 46.1MB/s]
# imagenette2.tgz:  98%|█████████▊| 1.53G/1.56G [00:35<00:00, 40.0MB/s]
# imagenette2.tgz:  98%|█████████▊| 1.53G/1.56G [00:35<00:00, 42.3MB/s]
# imagenette2.tgz:  99%|█████████▉| 1.54G/1.56G [00:35<00:00, 42.6MB/s]
# imagenette2.tgz:  99%|█████████▉| 1.54G/1.56G [00:35<00:00, 43.4MB/s]
# imagenette2.tgz: 1.56GB [00:35, 43.6MB/s]
# Calculate teacher channel mean & std: 100%|██████████| 230/230 [00:09<00:00, 24.69it/s]
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_st', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_ae', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_stae', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 4/4 [00:15<00:00,  3.77s/it]
# INFO: `Trainer.fit` stopped: `max_epochs=1` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=1` reached.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# INFO:
#   | Name                  | Type                     | Params | Mode
# ---------------------------------------------------------------------------
# 0 | model                 | EfficientAdModel         | 8.1 M  | train
# 1 | _transform            | Compose                  | 0      | train
# 2 | normalization_metrics | MetricCollection         | 0      | train
# 3 | image_threshold       | F1AdaptiveThreshold      | 0      | train
# 4 | pixel_threshold       | F1AdaptiveThreshold      | 0      | train
# 5 | image_metrics         | AnomalibMetricCollection | 0      | train
# 6 | pixel_metrics         | AnomalibMetricCollection | 0      | train
# ---------------------------------------------------------------------------
# 8.1 M     Trainable params
# 0         Non-trainable params
# 8.1 M     Total params
# 32.235    Total estimated model params size (MB)
# 46        Modules in train mode
# 7         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name                  | Type                     | Params | Mode
# ---------------------------------------------------------------------------
# 0 | model                 | EfficientAdModel         | 8.1 M  | train
# 1 | _transform            | Compose                  | 0      | train
# 2 | normalization_metrics | MetricCollection         | 0      | train
# 3 | image_threshold       | F1AdaptiveThreshold      | 0      | train
# 4 | pixel_threshold       | F1AdaptiveThreshold      | 0      | train
# 5 | image_metrics         | AnomalibMetricCollection | 0      | train
# 6 | pixel_metrics         | AnomalibMetricCollection | 0      | train
# ---------------------------------------------------------------------------
# 8.1 M     Trainable params
# 0         Non-trainable params
# 8.1 M     Total params
# 32.235    Total estimated model params size (MB)
# 46        Modules in train mode
# 7         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/anomalib/models/image/efficient_ad/lightning_model.py:98: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(
# Calculate teacher channel mean & std: 100%|██████████| 264/264 [00:11<00:00, 22.38it/s]
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_st', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_ae', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_stae', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 3/3 [00:05<00:00,  1.77s/it]
# INFO: `Trainer.fit` stopped: `max_epochs=1` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=1` reached.
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# INFO:
#   | Name                  | Type                     | Params | Mode
# ---------------------------------------------------------------------------
# 0 | model                 | EfficientAdModel         | 8.1 M  | train
# 1 | _transform            | Compose                  | 0      | train
# 2 | normalization_metrics | MetricCollection         | 0      | train
# 3 | image_threshold       | F1AdaptiveThreshold      | 0      | train
# 4 | pixel_threshold       | F1AdaptiveThreshold      | 0      | train
# 5 | image_metrics         | AnomalibMetricCollection | 0      | train
# 6 | pixel_metrics         | AnomalibMetricCollection | 0      | train
# ---------------------------------------------------------------------------
# 8.1 M     Trainable params
# 0         Non-trainable params
# 8.1 M     Total params
# 32.235    Total estimated model params size (MB)
# 46        Modules in train mode
# 7         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name                  | Type                     | Params | Mode
# ---------------------------------------------------------------------------
# 0 | model                 | EfficientAdModel         | 8.1 M  | train
# 1 | _transform            | Compose                  | 0      | train
# 2 | normalization_metrics | MetricCollection         | 0      | train
# 3 | image_threshold       | F1AdaptiveThreshold      | 0      | train
# 4 | pixel_threshold       | F1AdaptiveThreshold      | 0      | train
# 5 | image_metrics         | AnomalibMetricCollection | 0      | train
# 6 | pixel_metrics         | AnomalibMetricCollection | 0      | train
# ---------------------------------------------------------------------------
# 8.1 M     Trainable params
# 0         Non-trainable params
# 8.1 M     Total params
# 32.235    Total estimated model params size (MB)
# 46        Modules in train mode
# 7         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/anomalib/models/image/efficient_ad/lightning_model.py:98: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(
# Calculate teacher channel mean & std: 100%|██████████| 245/245 [00:13<00:00, 17.58it/s]
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_st', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_ae', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_stae', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/module.py:516: You called `self.log('train_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
# Validation: |          | 0/? [00:00<?, ?it/s]
# Calculate Validation Dataset Quantiles: 100%|██████████| 4/4 [00:13<00:00,  3.30s/it]
# INFO: `Trainer.fit` stopped: `max_epochs=1` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=1` reached.

# %%
results_EfAd = {}
predictions_EfAd = {}
for category in categories:
    # Perform inference
    predictions_EfAd[category] = engine_EfAd[category].predict(
        datamodule=dataset_EfAd[category],
        model=model_EfAd[category]
    )

    # Evaluate the model
    results_EfAd[category] = engine_EfAd[category].test(datamodule=dataset_EfAd[category], model=model_EfAd[category])
# Out:
# WARNING:anomalib.engine.engine:ckpt_path is not provided. Model weights will not be loaded.
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │    0.9494949579238892     │
# │       image_F1Score       │     0.929411768913269     │
# │        pixel_AUROC        │    0.8318764567375183     │
# │       pixel_F1Score       │    0.5901319980621338     │
# └───────────────────────────┴───────────────────────────┘
# WARNING:anomalib.engine.engine:ckpt_path is not provided. Model weights will not be loaded.
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │    0.9615706205368042     │
# │       image_F1Score       │    0.9322034120559692     │
# │        pixel_AUROC        │     0.82756108045578      │
# │       pixel_F1Score       │    0.27939656376838684    │
# └───────────────────────────┴───────────────────────────┘
# WARNING:anomalib.engine.engine:ckpt_path is not provided. Model weights will not be loaded.
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │    0.9762228727340698     │
# │       image_F1Score       │    0.9560439586639404     │
# │        pixel_AUROC        │    0.9614350199699402     │
# │       pixel_F1Score       │    0.45646703243255615    │
# └───────────────────────────┴───────────────────────────┘

# %% [markdown]
# #  *Results of EfficientAd*

# %%
for category in categories:
  print(f"Category: {category}")
  print(f"Detection AUROC: {results_EfAd[category][0]['image_AUROC']}")
  print(f"Segmentation AUROC: {results_EfAd[category][0]['pixel_AUROC']}\n")
# Out:
# Category: tile
# Detection AUROC: 0.9494949579238892
# Segmentation AUROC: 0.8318764567375183
#
# Category: grid
# Detection AUROC: 0.9615706205368042
# Segmentation AUROC: 0.82756108045578
#
# Category: leather
# Detection AUROC: 0.9762228727340698
# Segmentation AUROC: 0.9614350199699402

# %%
total_auroc = 0
for category in categories:
  total_auroc += results_EfAd[category][0]['image_AUROC']  # Using image_AUROC
avg_auroc = total_auroc / len(categories)
print(f"Average AUROC across categories (EfficientAd): {avg_auroc}")
# Out:
# Average AUROC across categories (EfficientAd): 0.9624294837315878

# %% [markdown]
# # *Visualisation for EfficientAd*

# %%
# Get a sample image of tile
sample_anomaly_map_tile = predictions_EfAd['tile'][0]['anomaly_maps'][0].squeeze().cpu().numpy()
sample_image_tile = predictions_EfAd['tile'][0]['image'][0][0].numpy()
visualize_results(sample_image_tile, sample_anomaly_map_tile)

# %%
# Get a sample image of grid
sample_anomaly_map_grid = predictions_EfAd['grid'][0]['anomaly_maps'][0].squeeze().cpu().numpy()
sample_image_grid = predictions_EfAd['grid'][0]['image'][0][0].numpy()
visualize_results(sample_image_grid, sample_anomaly_map_grid)

# %%
# Get a sample image of leather
sample_anomaly_map_leather = predictions_EfAd['leather'][0]['anomaly_maps'][0].squeeze().cpu().numpy()
sample_image_leather = predictions_EfAd['leather'][0]['image'][0][0].numpy()
visualize_results(sample_image_leather, sample_anomaly_map_leather)

# %% [markdown]
# ## *About EfficientAd*
#
# EfficientAD is a breakthrough in anomaly detection, achieving over 95% accuracy in benchmarking. It surpasses existing methods in both accuracy and efficiency.
#
# The EfficientAD model analyzed the image of tile, grid and leather.
# The anomaly map reveals main areas of anomalies. The most significant hotspots have red spectrum on heatmap, corresponding to the normal image. This area shows high intensity in the anomaly map, suggesting potential anomaly.
#
# EfficientAD drastically reduces the latency of processing one image from over 10ms to just 2ms. It can process up to 600 images per second, enabling fast handling of anomalies, evident from the above training part.
#
# The model uses an EfficientNetB0 backbone, known for its balance of accuracy and efficiency. It employs a deep funnel architecture to enhance understanding of complex patterns in images.
#
# EfficientAD uses an unsupervised learning approach. It's trained only on anomaly-free images from specific domains, making it versatile for different applications.
#
# EfficientAD combines a student-teacher model for detecting anomalous local features with an autoencoder for identifying logical anomalies.
#
# The model is particularly suited for manufacturing and industrial settings where rapid, accurate anomaly detection is crucial for productivity and safety.
#
# EfficientAD addresses the need for low computational cost in real-world applications, making it suitable for scenarios with strict runtime limits due to high production rates.

# %% [markdown]
# # Patchcore

# %%
# Initialize the model for each category

categories = ["tile", "grid", "leather"]
model_PtCore = {}
engine_PtCore={}
dataset_PtCore = {}
for category in categories:
    dataset_PtCore[category] = MVTec(root="path/to/mvtec", category=category, train_batch_size=1)
    model_PtCore[category] = Patchcore(pre_trained=True)
    engine_PtCore[category] = Engine(max_epochs=1)

    # Train the model
    engine_PtCore[category].fit(datamodule=dataset_PtCore[category], model=model_PtCore[category])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/276M [00:00<?, ?B/s]
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/optimizer.py:182: `LightningModule.configure_optimizers` returned `None`, this fit will run with no optimizer
# INFO:
#   | Name                  | Type                     | Params | Mode
# ---------------------------------------------------------------------------
# 0 | model                 | PatchcoreModel           | 24.9 M | train
# 1 | _transform            | Compose                  | 0      | train
# 2 | normalization_metrics | MetricCollection         | 0      | train
# 3 | image_threshold       | F1AdaptiveThreshold      | 0      | train
# 4 | pixel_threshold       | F1AdaptiveThreshold      | 0      | train
# 5 | image_metrics         | AnomalibMetricCollection | 0      | train
# 6 | pixel_metrics         | AnomalibMetricCollection | 0      | train
# ---------------------------------------------------------------------------
# 24.9 M    Trainable params
# 0         Non-trainable params
# 24.9 M    Total params
# 99.450    Total estimated model params size (MB)
# 17        Modules in train mode
# 174       Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name                  | Type                     | Params | Mode
# ---------------------------------------------------------------------------
# 0 | model                 | PatchcoreModel           | 24.9 M | train
# 1 | _transform            | Compose                  | 0      | train
# 2 | normalization_metrics | MetricCollection         | 0      | train
# 3 | image_threshold       | F1AdaptiveThreshold      | 0      | train
# 4 | pixel_threshold       | F1AdaptiveThreshold      | 0      | train
# 5 | image_metrics         | AnomalibMetricCollection | 0      | train
# 6 | pixel_metrics         | AnomalibMetricCollection | 0      | train
# ---------------------------------------------------------------------------
# 24.9 M    Trainable params
# 0         Non-trainable params
# 24.9 M    Total params
# 99.450    Total estimated model params size (MB)
# 17        Modules in train mode
# 174       Modules in eval mode
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Training: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/loops/optimization/automatic.py:132: `training_step` returned `None`. If this was on purpose, ignore this warning...
# Validation: |          | 0/? [00:00<?, ?it/s]
# Selecting Coreset Indices.:   0%|          | 0/18032 [00:00<?, ?it/s]
#
# Selecting Coreset Indices.:   0%|          | 1/18032 [00:00<1:55:11,  2.61it/s]
#
# Selecting Coreset Indices.:   0%|          | 7/18032 [00:00<16:46, 17.91it/s]
#
# Selecting Coreset Indices.:   0%|          | 14/18032 [00:00<09:25, 31.86it/s]
#
# Selecting Coreset Indices.:   0%|          | 25/18032 [00:00<05:44, 52.27it/s]
#
# Selecting Coreset Indices.:   0%|          | 36/18032 [00:00<04:29, 66.79it/s]
#
# Selecting Coreset Indices.:   0%|          | 46/18032 [00:00<03:59, 75.09it/s]
#
# Selecting Coreset Indices.:   0%|          | 55/18032 [00:01<03:53, 77.10it/s]
#
# Selecting Coreset Indices.:   0%|          | 64/18032 [00:01<04:03, 73.76it/s]
#
# Selecting Coreset Indices.:   0%|          | 72/18032 [00:01<04:14, 70.60it/s]
#
# Selecting Coreset Indices.:   0%|          | 80/18032 [00:01<04:06, 72.90it/s]
#
# Selecting Coreset Indices.:   0%|          | 88/18032 [00:01<04:06, 72.65it/s]
#
# Selecting Coreset Indices.:   1%|          | 96/18032 [00:01<04:17, 69.69it/s]
#
# Selecting Coreset Indices.:   1%|          | 109/18032 [00:01<03:31, 84.60it/s]
#
# Selecting Coreset Indices.:   1%|          | 127/18032 [00:01<02:41, 110.71it/s]
#
# Selecting Coreset Indices.:   1%|          | 139/18032 [00:01<02:43, 109.72it/s]
#
# Selecting Coreset Indices.:   1%|          | 151/18032 [00:02<03:09, 94.46it/s]
#
# Selecting Coreset Indices.:   1%|          | 162/18032 [00:02<03:37, 82.25it/s]
#
# Selecting Coreset Indices.:   1%|          | 171/18032 [00:02<03:55, 75.81it/s]
#
# Selecting Coreset Indices.:   1%|          | 180/18032 [00:02<04:09, 71.52it/s]
#
# Selecting Coreset Indices.:   1%|          | 190/18032 [00:02<03:53, 76.28it/s]
#
# Selecting Coreset Indices.:   1%|          | 200/18032 [00:02<03:38, 81.73it/s]
#
# Selecting Coreset Indices.:   1%|          | 209/18032 [00:02<03:58, 74.73it/s]
#
# Selecting Coreset Indices.:   1%|          | 217/18032 [00:03<04:20, 68.47it/s]
#
# Selecting Coreset Indices.:   1%|          | 225/18032 [00:03<04:16, 69.54it/s]
#
# Selecting Coreset Indices.:   1%|▏         | 233/18032 [00:03<04:27, 66.52it/s]
#
# Selecting Coreset Indices.:   1%|▏         | 240/18032 [00:03<04:32, 65.31it/s]
#
# Selecting Coreset Indices.:   1%|▏         | 247/18032 [00:03<04:32, 65.30it/s]
#
# Selecting Coreset Indices.:   1%|▏         | 255/18032 [00:03<04:20, 68.32it/s]
#
# Selecting Coreset Indices.:   1%|▏         | 265/18032 [00:03<03:53, 76.11it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 273/18032 [00:03<04:06, 72.13it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 281/18032 [00:04<04:13, 70.09it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 289/18032 [00:04<04:25, 66.85it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 297/18032 [00:04<04:16, 69.18it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 305/18032 [00:04<04:32, 65.11it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 312/18032 [00:04<04:27, 66.34it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 319/18032 [00:04<04:23, 67.30it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 327/18032 [00:04<04:11, 70.52it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 340/18032 [00:04<03:25, 86.00it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 351/18032 [00:04<03:14, 90.83it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 361/18032 [00:05<03:23, 87.01it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 370/18032 [00:05<03:30, 83.87it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 379/18032 [00:05<03:42, 79.51it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 388/18032 [00:05<04:07, 71.15it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 396/18032 [00:05<04:21, 67.50it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 404/18032 [00:05<04:09, 70.55it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 416/18032 [00:05<03:34, 82.08it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 426/18032 [00:05<03:29, 84.21it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 435/18032 [00:06<03:35, 81.58it/s]
#
# Selecting Coreset Indices.:   2%|▏         | 444/18032 [00:06<03:44, 78.37it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 452/18032 [00:06<04:00, 73.20it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 461/18032 [00:06<03:47, 77.36it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 470/18032 [00:06<03:38, 80.49it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 482/18032 [00:06<03:14, 90.27it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 495/18032 [00:06<02:52, 101.44it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 510/18032 [00:06<02:33, 114.37it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 529/18032 [00:06<02:09, 135.07it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 546/18032 [00:06<02:01, 143.89it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 561/18032 [00:07<02:03, 142.04it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 576/18032 [00:07<02:10, 133.85it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 590/18032 [00:07<02:12, 131.97it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 604/18032 [00:07<02:15, 128.79it/s]
#
# Selecting Coreset Indices.:   3%|▎         | 622/18032 [00:07<02:03, 141.07it/s]
#
# Selecting Coreset Indices.:   4%|▎         | 637/18032 [00:07<02:05, 138.22it/s]
#
# Selecting Coreset Indices.:   4%|▎         | 654/18032 [00:07<01:58, 146.78it/s]
#
# Selecting Coreset Indices.:   4%|▎         | 673/18032 [00:07<01:49, 158.11it/s]
#
# Selecting Coreset Indices.:   4%|▍         | 692/18032 [00:07<01:44, 165.34it/s]
#
# Selecting Coreset Indices.:   4%|▍         | 711/18032 [00:08<01:41, 170.44it/s]
#
# Selecting Coreset Indices.:   4%|▍         | 731/18032 [00:08<01:37, 177.38it/s]
#
# Selecting Coreset Indices.:   4%|▍         | 751/18032 [00:08<01:34, 182.49it/s]
#
# Selecting Coreset Indices.:   4%|▍         | 771/18032 [00:08<01:32, 186.96it/s]
#
# Selecting Coreset Indices.:   4%|▍         | 791/18032 [00:08<01:31, 189.18it/s]
#
# Selecting Coreset Indices.:   4%|▍         | 811/18032 [00:08<01:30, 191.33it/s]
#
# Selecting Coreset Indices.:   5%|▍         | 831/18032 [00:08<01:29, 192.56it/s]
#
# Selecting Coreset Indices.:   5%|▍         | 851/18032 [00:08<01:28, 193.51it/s]
#
# Selecting Coreset Indices.:   5%|▍         | 871/18032 [00:08<01:28, 194.36it/s]
#
# Selecting Coreset Indices.:   5%|▍         | 891/18032 [00:08<01:27, 195.08it/s]
#
# Selecting Coreset Indices.:   5%|▌         | 911/18032 [00:09<01:27, 195.72it/s]
#
# Selecting Coreset Indices.:   5%|▌         | 931/18032 [00:09<01:27, 195.84it/s]
#
# Selecting Coreset Indices.:   5%|▌         | 951/18032 [00:09<01:27, 195.48it/s]
#
# Selecting Coreset Indices.:   5%|▌         | 971/18032 [00:09<01:27, 195.51it/s]
#
# Selecting Coreset Indices.:   5%|▌         | 991/18032 [00:09<01:27, 195.78it/s]
#
# Selecting Coreset Indices.:   6%|▌         | 1011/18032 [00:09<01:26, 196.12it/s]
#
# Selecting Coreset Indices.:   6%|▌         | 1031/18032 [00:09<01:26, 196.09it/s]
#
# Selecting Coreset Indices.:   6%|▌         | 1051/18032 [00:09<01:27, 195.14it/s]
#
# Selecting Coreset Indices.:   6%|▌         | 1071/18032 [00:09<01:26, 195.66it/s]
#
# Selecting Coreset Indices.:   6%|▌         | 1091/18032 [00:10<01:26, 195.89it/s]
#
# Selecting Coreset Indices.:   6%|▌         | 1111/18032 [00:10<01:26, 196.15it/s]
#
# Selecting Coreset Indices.:   6%|▋         | 1131/18032 [00:10<01:26, 196.16it/s]
#
# Selecting Coreset Indices.:   6%|▋         | 1151/18032 [00:10<01:26, 196.26it/s]
#
# Selecting Coreset Indices.:   6%|▋         | 1171/18032 [00:10<01:25, 196.51it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1191/18032 [00:10<01:25, 195.91it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1211/18032 [00:10<01:25, 195.77it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1231/18032 [00:10<01:26, 195.28it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1251/18032 [00:10<01:26, 194.86it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1271/18032 [00:10<01:26, 193.86it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1291/18032 [00:11<01:26, 194.16it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1311/18032 [00:11<01:26, 193.05it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1331/18032 [00:11<01:26, 194.17it/s]
#
# Selecting Coreset Indices.:   7%|▋         | 1351/18032 [00:11<01:25, 195.01it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1371/18032 [00:11<01:25, 195.26it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1391/18032 [00:11<01:25, 195.09it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1411/18032 [00:11<01:25, 195.42it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1431/18032 [00:11<01:25, 194.90it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1451/18032 [00:11<01:25, 194.61it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1471/18032 [00:11<01:24, 195.30it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1491/18032 [00:12<01:24, 195.14it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1511/18032 [00:12<01:24, 195.20it/s]
#
# Selecting Coreset Indices.:   8%|▊         | 1531/18032 [00:12<01:24, 195.43it/s]
#
# Selecting Coreset Indices.:   9%|▊         | 1551/18032 [00:12<01:24, 195.71it/s]
#
# Selecting Coreset Indices.:   9%|▊         | 1571/18032 [00:12<01:24, 195.55it/s]
#
# Selecting Coreset Indices.:   9%|▉         | 1591/18032 [00:12<01:23, 195.94it/s]
#
# Selecting Coreset Indices.:   9%|▉         | 1611/18032 [00:12<01:24, 195.47it/s]
#
# Selecting Coreset Indices.:   9%|▉         | 1631/18032 [00:12<01:24, 194.75it/s]
#
# Selecting Coreset Indices.:   9%|▉         | 1651/18032 [00:12<01:23, 195.25it/s]
#
# Selecting Coreset Indices.:   9%|▉         | 1671/18032 [00:12<01:23, 195.64it/s]
#
# Selecting Coreset Indices.:   9%|▉         | 1691/18032 [00:13<01:23, 195.77it/s]
#
# Selecting Coreset Indices.:   9%|▉         | 1711/18032 [00:13<01:23, 195.25it/s]
#
# Selecting Coreset Indices.:  10%|▉         | 1731/18032 [00:13<01:23, 194.71it/s]
#
# Selecting Coreset Indices.:  10%|▉         | 1751/18032 [00:13<01:23, 195.28it/s]
#
# Selecting Coreset Indices.:  10%|▉         | 1771/18032 [00:13<01:23, 195.36it/s]
#
# Selecting Coreset Indices.:  10%|▉         | 1791/18032 [00:13<01:23, 194.49it/s]
#
# Selecting Coreset Indices.:  10%|█         | 1811/18032 [00:13<01:23, 194.43it/s]
#
# Selecting Coreset Indices.:  10%|█         | 1831/18032 [00:13<01:23, 192.97it/s]
#
# Selecting Coreset Indices.:  10%|█         | 1851/18032 [00:13<01:23, 193.67it/s]
#
# Selecting Coreset Indices.:  10%|█         | 1871/18032 [00:14<01:23, 194.37it/s]
#
# Selecting Coreset Indices.:  10%|█         | 1891/18032 [00:14<01:22, 194.93it/s]
#
# Selecting Coreset Indices.:  11%|█         | 1911/18032 [00:14<01:22, 195.46it/s]
#
# Selecting Coreset Indices.:  11%|█         | 1931/18032 [00:14<01:22, 195.94it/s]
#
# Selecting Coreset Indices.:  11%|█         | 1951/18032 [00:14<01:21, 196.18it/s]
#
# Selecting Coreset Indices.:  11%|█         | 1971/18032 [00:14<01:21, 196.41it/s]
#
# Selecting Coreset Indices.:  11%|█         | 1991/18032 [00:14<01:21, 195.82it/s]
#
# Selecting Coreset Indices.:  11%|█         | 2011/18032 [00:14<01:24, 190.67it/s]
#
# Selecting Coreset Indices.:  11%|█▏        | 2031/18032 [00:14<01:23, 192.10it/s]
#
# Selecting Coreset Indices.:  11%|█▏        | 2051/18032 [00:14<01:23, 192.27it/s]
#
# Selecting Coreset Indices.:  11%|█▏        | 2071/18032 [00:15<01:22, 193.45it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2091/18032 [00:15<01:21, 194.62it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2111/18032 [00:15<01:21, 194.80it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2131/18032 [00:15<01:21, 195.33it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2151/18032 [00:15<01:21, 195.70it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2171/18032 [00:15<01:21, 195.68it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2191/18032 [00:15<01:20, 195.85it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2211/18032 [00:15<01:23, 189.15it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2231/18032 [00:15<01:22, 190.91it/s]
#
# Selecting Coreset Indices.:  12%|█▏        | 2251/18032 [00:15<01:22, 192.04it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2271/18032 [00:16<01:21, 193.14it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2291/18032 [00:16<01:21, 194.25it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2311/18032 [00:16<01:20, 195.00it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2331/18032 [00:16<01:20, 195.70it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2351/18032 [00:16<01:20, 195.62it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2371/18032 [00:16<01:19, 196.08it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2391/18032 [00:16<01:20, 195.39it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2411/18032 [00:16<01:21, 192.10it/s]
#
# Selecting Coreset Indices.:  13%|█▎        | 2431/18032 [00:16<01:21, 190.83it/s]
#
# Selecting Coreset Indices.:  14%|█▎        | 2451/18032 [00:17<01:21, 191.12it/s]
#
# Selecting Coreset Indices.:  14%|█▎        | 2471/18032 [00:17<01:21, 191.24it/s]
#
# Selecting Coreset Indices.:  14%|█▍        | 2491/18032 [00:17<01:20, 192.17it/s]
#
# Selecting Coreset Indices.:  14%|█▍        | 2511/18032 [00:17<01:20, 191.76it/s]
#
# Selecting Coreset Indices.:  14%|█▍        | 2531/18032 [00:17<01:20, 191.83it/s]
#
# Selecting Coreset Indices.:  14%|█▍        | 2551/18032 [00:17<01:21, 191.03it/s]
#
# Selecting Coreset Indices.:  14%|█▍        | 2571/18032 [00:17<01:21, 189.61it/s]
#
# Selecting Coreset Indices.:  14%|█▍        | 2591/18032 [00:17<01:20, 190.91it/s]
#
# Selecting Coreset Indices.:  14%|█▍        | 2611/18032 [00:17<01:21, 189.71it/s]
#
# Selecting Coreset Indices.:  15%|█▍        | 2631/18032 [00:17<01:20, 191.29it/s]
#
# Selecting Coreset Indices.:  15%|█▍        | 2651/18032 [00:18<01:20, 191.65it/s]
#
# Selecting Coreset Indices.:  15%|█▍        | 2671/18032 [00:18<01:20, 191.37it/s]
#
# Selecting Coreset Indices.:  15%|█▍        | 2691/18032 [00:18<01:20, 191.62it/s]
#
# Selecting Coreset Indices.:  15%|█▌        | 2711/18032 [00:18<01:20, 190.76it/s]
#
# Selecting Coreset Indices.:  15%|█▌        | 2731/18032 [00:18<01:20, 190.60it/s]
#
# Selecting Coreset Indices.:  15%|█▌        | 2751/18032 [00:18<01:19, 191.10it/s]
#
# Selecting Coreset Indices.:  15%|█▌        | 2771/18032 [00:18<01:20, 189.78it/s]
#
# Selecting Coreset Indices.:  15%|█▌        | 2791/18032 [00:18<01:20, 190.37it/s]
#
# Selecting Coreset Indices.:  16%|█▌        | 2811/18032 [00:18<01:20, 189.62it/s]
#
# Selecting Coreset Indices.:  16%|█▌        | 2830/18032 [00:18<01:20, 189.04it/s]
#
# Selecting Coreset Indices.:  16%|█▌        | 2850/18032 [00:19<01:19, 190.58it/s]
#
# Selecting Coreset Indices.:  16%|█▌        | 2870/18032 [00:19<01:19, 190.84it/s]
#
# Selecting Coreset Indices.:  16%|█▌        | 2890/18032 [00:19<01:19, 190.71it/s]
#
# Selecting Coreset Indices.:  16%|█▌        | 2910/18032 [00:19<01:18, 191.51it/s]
#
# Selecting Coreset Indices.:  16%|█▌        | 2930/18032 [00:19<01:18, 191.86it/s]
#
# Selecting Coreset Indices.:  16%|█▋        | 2950/18032 [00:19<01:18, 191.77it/s]
#
# Selecting Coreset Indices.:  16%|█▋        | 2970/18032 [00:19<01:19, 189.59it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 2989/18032 [00:19<01:19, 189.35it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3009/18032 [00:19<01:19, 189.86it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3029/18032 [00:20<01:18, 190.74it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3049/18032 [00:20<01:18, 191.79it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3069/18032 [00:20<01:17, 192.51it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3089/18032 [00:20<01:18, 189.83it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3108/18032 [00:20<01:19, 188.52it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3127/18032 [00:20<01:21, 182.34it/s]
#
# Selecting Coreset Indices.:  17%|█▋        | 3146/18032 [00:20<01:21, 182.07it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3166/18032 [00:20<01:20, 184.91it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3185/18032 [00:20<01:20, 184.23it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3204/18032 [00:20<01:20, 183.66it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3223/18032 [00:21<01:20, 183.13it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3242/18032 [00:21<01:21, 180.66it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3261/18032 [00:21<01:23, 176.65it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3280/18032 [00:21<01:22, 179.44it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3300/18032 [00:21<01:20, 182.93it/s]
#
# Selecting Coreset Indices.:  18%|█▊        | 3319/18032 [00:21<01:20, 183.72it/s]
#
# Selecting Coreset Indices.:  19%|█▊        | 3338/18032 [00:21<01:20, 183.29it/s]
#
# Selecting Coreset Indices.:  19%|█▊        | 3357/18032 [00:21<01:19, 184.04it/s]
#
# Selecting Coreset Indices.:  19%|█▊        | 3377/18032 [00:21<01:18, 186.87it/s]
#
# Selecting Coreset Indices.:  19%|█▉        | 3396/18032 [00:22<01:18, 186.52it/s]
#
# Selecting Coreset Indices.:  19%|█▉        | 3415/18032 [00:22<01:18, 185.66it/s]
#
# Selecting Coreset Indices.:  19%|█▉        | 3434/18032 [00:22<01:18, 184.83it/s]
#
# Selecting Coreset Indices.:  19%|█▉        | 3454/18032 [00:22<01:17, 187.25it/s]
#
# Selecting Coreset Indices.:  19%|█▉        | 3474/18032 [00:22<01:17, 188.75it/s]
#
# Selecting Coreset Indices.:  19%|█▉        | 3493/18032 [00:22<01:16, 188.97it/s]
#
# Selecting Coreset Indices.:  19%|█▉        | 3513/18032 [00:22<01:16, 189.51it/s]
#
# Selecting Coreset Indices.:  20%|█▉        | 3532/18032 [00:22<01:16, 188.55it/s]
#
# Selecting Coreset Indices.:  20%|█▉        | 3551/18032 [00:22<01:17, 187.11it/s]
#
/s]
#
# Selecting Coreset Indices.:  28%|██▊       | 5119/18032 [00:31<01:07, 191.16it/s]
#
# Selecting Coreset Indices.:  28%|██▊       | 5139/18032 [00:31<01:07, 191.51it/s]
#
# Selecting Coreset Indices.:  29%|██▊       | 5159/18032 [00:31<01:07, 191.67it/s]
#
# Selecting Coreset Indices.:  29%|██▊       | 5179/18032 [00:31<01:06, 192.10it/s]
#
# Selecting Coreset Indices.:  29%|██▉       | 5199/18032 [00:31<01:06, 192.47it/s]
#
# Selecting Coreset Indices.:  29%|██▉       | 5219/18032 [00:31<01:08, 187.67it/s]
#
# Selecting Coreset Indices.:  29%|██▉       | 5238/18032 [00:31<01:10, 180.98it/s]
#
# Selecting Coreset Indices.:  29%|██▉       | 5258/18032 [00:31<01:09, 184.64it/s]
#
# Selecting Coreset Indices.:  29%|██▉       | 5278/18032 [00:32<01:08, 187.05it/s]
#
# Selecting Coreset Indices.:  29%|██▉       | 5298/18032 [00:32<01:07, 188.74it/s]
#
# Selecting Coreset Indices.:  29%|██▉       | 5318/18032 [00:32<01:07, 189.33it/s]
#
# Selecting Coreset Indices.:  30%|██▉       | 5338/18032 [00:32<01:06, 190.27it/s]
#
# Selecting Coreset Indices.:  30%|██▉       | 5358/18032 [00:32<01:06, 191.37it/s]
#
# Selecting Coreset Indices.:  30%|██▉       | 5378/18032 [00:32<01:05, 192.14it/s]
#
# Selecting Coreset Indices.:  30%|██▉       | 5398/18032 [00:32<01:05, 192.53it/s]
#
# Selecting Coreset Indices.:  30%|███       | 5418/18032 [00:32<01:06, 188.48it/s]
#
# Selecting Coreset Indices.:  30%|███       | 5437/18032 [00:32<01:07, 185.74it/s]
#
# Selecting Coreset Indices.:  30%|███       | 5456/18032 [00:32<01:08, 183.25it/s]
#
# Selecting Coreset Indices.:  30%|███       | 5475/18032 [00:33<01:08, 183.81it/s]
#
# Selecting Coreset Indices.:  30%|███       | 5494/18032 [00:33<01:08, 182.74it/s]
#
# Selecting Coreset Indices.:  31%|███       | 5513/18032 [00:33<01:08, 183.70it/s]
#
# Selecting Coreset Indices.:  31%|███       | 5532/18032 [00:33<01:07, 185.05it/s]
#
# Selecting Coreset Indices.:  31%|███       | 5551/18032 [00:33<01:07, 185.82it/s]
#
# Selecting Coreset Indices.:  31%|███       | 5570/18032 [00:33<01:06, 186.68it/s]
#
# Selecting Coreset Indices.:  31%|███       | 5589/18032 [00:33<01:07, 185.24it/s]
#
# Selecting Coreset Indices.:  31%|███       | 5608/18032 [00:33<01:07, 182.99it/s]
#
# Selecting Coreset Indices.:  31%|███       | 5627/18032 [00:33<01:11, 174.67it/s]
#
# Selecting Coreset Indices.:  31%|███▏      | 5646/18032 [00:34<01:09, 178.92it/s]
#
# Selecting Coreset Indices.:  31%|███▏      | 5666/18032 [00:34<01:07, 182.54it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 5686/18032 [00:34<01:06, 186.12it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 5706/18032 [00:34<01:05, 187.81it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 5726/18032 [00:34<01:05, 189.01it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 5746/18032 [00:34<01:04, 190.67it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 5766/18032 [00:34<01:04, 190.93it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 5786/18032 [00:34<01:04, 190.11it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 5806/18032 [00:34<01:03, 191.19it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 5826/18032 [00:34<01:05, 186.92it/s]
#
# Selecting Coreset Indices.:  32%|███▏      | 5846/18032 [00:35<01:04, 188.98it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 5865/18032 [00:35<01:04, 188.36it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 5884/18032 [00:35<01:04, 188.12it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 5903/18032 [00:35<01:04, 187.27it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 5923/18032 [00:35<01:03, 189.49it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 5943/18032 [00:35<01:03, 190.96it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 5963/18032 [00:35<01:03, 189.92it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 5982/18032 [00:35<01:04, 186.22it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 6002/18032 [00:35<01:03, 188.81it/s]
#
# Selecting Coreset Indices.:  33%|███▎      | 6022/18032 [00:35<01:03, 190.60it/s]
#
# Selecting Coreset Indices.:  34%|███▎      | 6042/18032 [00:36<01:04, 185.60it/s]
#
# Selecting Coreset Indices.:  34%|███▎      | 6062/18032 [00:36<01:03, 188.11it/s]
#
# Selecting Coreset Indices.:  34%|███▎      | 6082/18032 [00:36<01:02, 190.11it/s]
#
# Selecting Coreset Indices.:  34%|███▍      | 6102/18032 [00:36<01:02, 191.23it/s]
#
# Selecting Coreset Indices.:  34%|███▍      | 6122/18032 [00:36<01:02, 191.76it/s]
#
# Selecting Coreset Indices.:  34%|███▍      | 6142/18032 [00:36<01:02, 190.26it/s]
#
# Selecting Coreset Indices.:  34%|███▍      | 6162/18032 [00:36<01:01, 192.61it/s]
#
# Selecting Coreset Indices.:  34%|███▍      | 6182/18032 [00:36<01:01, 193.40it/s]
#
# Selecting Coreset Indices.:  34%|███▍      | 6202/18032 [00:36<01:00, 194.01it/s]
#
# Selecting Coreset Indices.:  35%|███▍      | 6222/18032 [00:37<01:00, 194.50it/s]
#
# Selecting Coreset Indices.:  35%|███▍      | 6242/18032 [00:37<01:00, 194.46it/s]
#
# Selecting Coreset Indices.:  35%|███▍      | 6262/18032 [00:37<01:00, 194.95it/s]
#
# Selecting Coreset Indices.:  35%|███▍      | 6282/18032 [00:37<01:00, 194.53it/s]
#
# Selecting Coreset Indices.:  35%|███▍      | 6302/18032 [00:37<01:00, 194.75it/s]
#
# Selecting Coreset Indices.:  35%|███▌      | 6322/18032 [00:37<00:59, 195.46it/s]
#
# Selecting Coreset Indices.:  35%|███▌      | 6342/18032 [00:37<00:59, 195.11it/s]
#
# Selecting Coreset Indices.:  35%|███▌      | 6362/18032 [00:37<01:00, 194.33it/s]
#
# Selecting Coreset Indices.:  35%|███▌      | 6382/18032 [00:37<00:59, 194.58it/s]
#
# Selecting Coreset Indices.:  36%|███▌      | 6402/18032 [00:37<00:59, 194.27it/s]
#
# Selecting Coreset Indices.:  36%|███▌      | 6422/18032 [00:38<00:59, 194.88it/s]
#
# Selecting Coreset Indices.:  36%|███▌      | 6442/18032 [00:38<01:00, 192.78it/s]
#
# Selecting Coreset Indices.:  36%|███▌      | 6462/18032 [00:38<00:59, 193.98it/s]
#
# Selecting Coreset Indices.:  36%|███▌      | 6482/18032 [00:38<00:59, 195.07it/s]
#
# Selecting Coreset Indices.:  36%|███▌      | 6502/18032 [00:38<00:58, 195.87it/s]
#
# Selecting Coreset Indices.:  36%|███▌      | 6522/18032 [00:38<00:58, 196.35it/s]
#
# Selecting Coreset Indices.:  36%|███▋      | 6542/18032 [00:38<00:58, 195.87it/s]
#
# Selecting Coreset Indices.:  36%|███▋      | 6562/18032 [00:38<00:59, 194.29it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 6582/18032 [00:38<00:59, 193.80it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 6602/18032 [00:38<00:58, 194.12it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 6622/18032 [00:39<00:58, 194.98it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 6642/18032 [00:39<00:58, 195.05it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 6662/18032 [00:39<00:58, 194.99it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 6682/18032 [00:39<00:58, 195.42it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 6702/18032 [00:39<00:57, 195.86it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 6722/18032 [00:39<00:57, 195.53it/s]
#
# Selecting Coreset Indices.:  37%|███▋      | 6742/18032 [00:39<00:58, 193.97it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 6762/18032 [00:39<00:58, 193.42it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 6782/18032 [00:39<00:58, 193.09it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 6802/18032 [00:40<00:58, 192.81it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 6822/18032 [00:40<00:57, 193.61it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 6842/18032 [00:40<00:57, 193.86it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 6862/18032 [00:40<00:57, 194.42it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 6882/18032 [00:40<00:57, 195.29it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 6902/18032 [00:40<00:56, 195.84it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 6922/18032 [00:40<00:57, 194.54it/s]
#
# Selecting Coreset Indices.:  38%|███▊      | 6942/18032 [00:40<00:57, 194.17it/s]
#
# Selecting Coreset Indices.:  39%|███▊      | 6962/18032 [00:40<00:56, 194.35it/s]
#
# Selecting Coreset Indices.:  39%|███▊      | 6982/18032 [00:40<00:56, 194.63it/s]
#
# Selecting Coreset Indices.:  39%|███▉      | 7002/18032 [00:41<00:56, 195.18it/s]
#
# Selecting Coreset Indices.:  39%|███▉      | 7022/18032 [00:41<00:56, 195.24it/s]
#
# Selecting Coreset Indices.:  39%|███▉      | 7042/18032 [00:41<00:56, 195.14it/s]
#
# Selecting Coreset Indices.:  39%|███▉      | 7062/18032 [00:41<00:56, 195.63it/s]
#
# Selecting Coreset Indices.:  39%|███▉      | 7082/18032 [00:41<00:56, 195.50it/s]
#
# Selecting Coreset Indices.:  39%|███▉      | 7102/18032 [00:41<00:55, 195.51it/s]
#
# Selecting Coreset Indices.:  39%|███▉      | 7122/18032 [00:41<00:56, 194.43it/s]
#
# Selecting Coreset Indices.:  40%|███▉      | 7142/18032 [00:41<00:56, 193.87it/s]
#
# Selecting Coreset Indices.:  40%|███▉      | 7162/18032 [00:41<00:55, 194.63it/s]
#
# Selecting Coreset Indices.:  40%|███▉      | 7182/18032 [00:41<00:55, 194.24it/s]
#
# Selecting Coreset Indices.:  40%|███▉      | 7202/18032 [00:42<00:55, 195.08it/s]
#
# Selecting Coreset Indices.:  40%|████      | 7222/18032 [00:42<00:55, 194.85it/s]
#
# Selecting Coreset Indices.:  40%|████      | 7242/18032 [00:42<00:55, 194.80it/s]
#
# Selecting Coreset Indices.:  40%|████      | 7262/18032 [00:42<00:55, 194.70it/s]
#
# Selecting Coreset Indices.:  40%|████      | 7282/18032 [00:42<00:55, 195.00it/s]
#
# Selecting Coreset Indices.:  40%|████      | 7302/18032 [00:42<00:55, 194.63it/s]
#
# Selecting Coreset Indices.:  41%|████      | 7322/18032 [00:42<00:54, 195.13it/s]
#
# Selecting Coreset Indices.:  41%|████      | 7342/18032 [00:42<00:54, 194.52it/s]
# Selecting Coreset Indices.:  54%|█████▍    | 9718/18032 [00:55<00:43, 190.29it/s]
#
# Selecting Coreset Indices.:  54%|█████▍    | 9738/18032 [00:55<00:43, 191.22it/s]
#
# Selecting Coreset Indices.:  54%|█████▍    | 9758/18032 [00:55<00:43, 191.76it/s]
#
# Selecting Coreset Indices.:  54%|█████▍    | 9778/18032 [00:55<00:42, 192.20it/s]
#
# Selecting Coreset Indices.:  54%|█████▍    | 9798/18032 [00:55<00:42, 192.46it/s]
#
# Selecting Coreset Indices.:  54%|█████▍    | 9818/18032 [00:55<00:43, 188.39it/s]
#
# Selecting Coreset Indices.:  55%|█████▍    | 9837/18032 [00:55<00:44, 183.69it/s]
#
# ...
#
# Selecting Coreset Indices.:  81%|████████  | 15570/19208 [01:28<00:20, 176.51it/s]
#
# Selecting Coreset Indices.:  81%|████████  | 15589/19208 [01:28<00:20, 178.51it/s]
#
# Selecting Coreset Indices.:  81%|████████▏ | 15608/19208 [01:28<00:19, 181.60it/s]
#
# Selecting Coreset Indices.:  81%|████████▏ | 15627/19208 [01:28<00:19, 182.97it/s]
#
# Selecting Coreset Indices.:  81%|████████▏ | 15646/19208 [01:28<00:19, 181.95it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 15666/19208 [01:29<00:19, 184.61it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 15685/19208 [01:29<00:19, 184.96it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 15704/19208 [01:29<00:18, 184.92it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 15723/19208 [01:29<00:19, 177.06it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 15741/19208 [01:29<00:19, 176.20it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 15759/19208 [01:29<00:19, 175.43it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 15777/19208 [01:29<00:19, 176.29it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 15797/19208 [01:29<00:18, 180.82it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 15816/19208 [01:29<00:18, 182.08it/s]
#
# Selecting Coreset Indices.:  82%|████████▏ | 15836/19208 [01:30<00:18, 184.59it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 15855/19208 [01:30<00:18, 185.21it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 15874/19208 [01:30<00:18, 182.93it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 15893/19208 [01:30<00:18, 181.72it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 15912/19208 [01:30<00:18, 178.45it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 15930/19208 [01:30<00:18, 178.76it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 15949/19208 [01:30<00:18, 180.75it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 15968/19208 [01:30<00:17, 182.79it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 15987/19208 [01:30<00:17, 183.93it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 16006/19208 [01:30<00:17, 183.43it/s]
#
# Selecting Coreset Indices.:  83%|████████▎ | 16025/19208 [01:31<00:17, 184.85it/s]
#
# Selecting Coreset Indices.:  84%|████████▎ | 16044/19208 [01:31<00:17, 185.68it/s]
#
# Selecting Coreset Indices.:  84%|████████▎ | 16063/19208 [01:31<00:16, 186.07it/s]
#
# Selecting Coreset Indices.:  84%|████████▎ | 16082/19208 [01:31<00:16, 186.43it/s]
#
# Selecting Coreset Indices.:  84%|████████▍ | 16102/19208 [01:31<00:16, 187.76it/s]
#
# Selecting Coreset Indices.:  84%|████████▍ | 16121/19208 [01:31<00:16, 188.12it/s]
#
# Selecting Coreset Indices.:  84%|████████▍ | 16140/19208 [01:31<00:16, 186.76it/s]
#
# Selecting Coreset Indices.:  84%|████████▍ | 16159/19208 [01:31<00:16, 187.01it/s]
#
# Selecting Coreset Indices.:  84%|████████▍ | 16178/19208 [01:31<00:16, 186.45it/s]
#
/s]
#
# Selecting Coreset Indices.:  88%|████████▊ | 16978/19208 [01:36<00:12, 183.38it/s]
#
# Selecting Coreset Indices.:  88%|████████▊ | 16997/19208 [01:36<00:11, 185.20it/s]
#
# Selecting Coreset Indices.:  89%|████████▊ | 17016/19208 [01:36<00:11, 184.86it/s]
#
# Selecting Coreset Indices.:  89%|████████▊ | 17035/19208 [01:36<00:11, 185.52it/s]
#
# Selecting Coreset Indices.:  89%|████████▉ | 17054/19208 [01:36<00:11, 185.23it/s]
#
# Selecting Coreset Indices.:  89%|████████▉ | 17073/19208 [01:36<00:11, 186.02it/s]
#
# Selecting Coreset Indices.:  89%|████████▉ | 17092/19208 [01:36<00:11, 184.51it/s]
#
# Selecting Coreset Indices.:  89%|████████▉ | 17111/19208 [01:36<00:11, 185.32it/s]
#
# Selecting Coreset Indices.:  89%|████████▉ | 17130/19208 [01:36<00:11, 182.62it/s]
#
# Selecting Coreset Indices.:  89%|████████▉ | 17149/19208 [01:37<00:11, 177.98it/s]
#
# Selecting Coreset Indices.:  89%|████████▉ | 17167/19208 [01:37<00:11, 178.19it/s]
#
# Selecting Coreset Indices.:  89%|████████▉ | 17186/19208 [01:37<00:11, 180.83it/s]
#
# Selecting Coreset Indices.:  90%|████████▉ | 17205/19208 [01:37<00:10, 182.97it/s]
#
# Selecting Coreset Indices.:  90%|████████▉ | 17224/19208 [01:37<00:10, 184.70it/s]
#
# Selecting Coreset Indices.:  90%|████████▉ | 17244/19208 [01:37<00:10, 186.49it/s]
#
# Selecting Coreset Indices.:  90%|████████▉ | 17263/19208 [01:37<00:10, 186.13it/s]
#
# Selecting Coreset Indices.:  90%|████████▉ | 17282/19208 [01:37<00:10, 186.76it/s]
#
# Selecting Coreset Indices.:  90%|█████████ | 17301/19208 [01:37<00:10, 186.90it/s]
#
# Selecting Coreset Indices.:  90%|█████████ | 17320/19208 [01:38<00:10, 186.66it/s]
#
# Selecting Coreset Indices.:  90%|█████████ | 17339/19208 [01:38<00:10, 183.77it/s]
#
# Selecting Coreset Indices.:  90%|█████████ | 17358/19208 [01:38<00:10, 181.33it/s]
#
# Selecting Coreset Indices.:  90%|█████████ | 17377/19208 [01:38<00:10, 182.07it/s]
#
# Selecting Coreset Indices.:  91%|█████████ | 17396/19208 [01:38<00:09, 182.28it/s]
#
# Selecting Coreset Indices.:  91%|█████████ | 17415/19208 [01:38<00:10, 175.36it/s]
#
# Selecting Coreset Indices.:  91%|█████████ | 17433/19208 [01:38<00:10, 170.85it/s]
#
# Selecting Coreset Indices.:  91%|█████████ | 17452/19208 [01:38<00:10, 174.83it/s]
#
# Selecting Coreset Indices.:  91%|█████████ | 17471/19208 [01:38<00:09, 178.67it/s]
#
# Selecting Coreset Indices.:  91%|█████████ | 17490/19208 [01:38<00:09, 181.40it/s]
#
# Selecting Coreset Indices.:  91%|█████████ | 17510/19208 [01:39<00:09, 184.73it/s]
#
# Selecting Coreset Indices.:  91%|█████████▏| 17529/19208 [01:39<00:09, 185.74it/s]
#
# Selecting Coreset Indices.:  91%|█████████▏| 17549/19208 [01:39<00:08, 187.48it/s]
#
# Selecting Coreset Indices.:  91%|█████████▏| 17569/19208 [01:39<00:08, 188.65it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 17589/19208 [01:39<00:08, 190.63it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 17609/19208 [01:39<00:08, 190.72it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 17629/19208 [01:39<00:08, 190.91it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 17649/19208 [01:39<00:08, 189.76it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 17668/19208 [01:39<00:08, 188.30it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 17687/19208 [01:40<00:08, 188.73it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 17706/19208 [01:40<00:08, 185.05it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 17725/19208 [01:40<00:08, 178.70it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 17744/19208 [01:40<00:08, 181.05it/s]
#
# Selecting Coreset Indices.:  92%|█████████▏| 17764/19208 [01:40<00:07, 183.96it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 17783/19208 [01:40<00:07, 184.84it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 17803/19208 [01:40<00:07, 187.03it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 17823/19208 [01:40<00:07, 188.48it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 17843/19208 [01:40<00:07, 189.78it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 17863/19208 [01:40<00:07, 190.41it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 17883/19208 [01:41<00:06, 191.22it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 17903/19208 [01:41<00:06, 191.83it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 17923/19208 [01:41<00:06, 191.86it/s]
#
# Selecting Coreset Indices.:  93%|█████████▎| 17943/19208 [01:41<00:06, 191.35it/s]
#
# Selecting Coreset Indices.:  94%|█████████▎| 17963/19208 [01:41<00:06, 192.04it/s]
#
# Selecting Coreset Indices.:  94%|█████████▎| 17983/19208 [01:41<00:06, 192.37it/s]
#
# Selecting Coreset Indices.:  94%|█████████▎| 18003/19208 [01:41<00:06, 191.98it/s]
#
# Selecting Coreset Indices.:  94%|█████████▍| 18023/19208 [01:41<00:06, 192.31it/s]
#
# Selecting Coreset Indices.:  94%|█████████▍| 18043/19208 [01:41<00:06, 191.87it/s]
#
# Selecting Coreset Indices.:  94%|█████████▍| 18063/19208 [01:42<00:05, 191.28it/s]
#
# Selecting Coreset Indices.:  94%|█████████▍| 18083/19208 [01:42<00:05, 191.59it/s]
#
# Selecting Coreset Indices.:  94%|█████████▍| 18103/19208 [01:42<00:05, 191.84it/s]
#
# Selecting Coreset Indices.:  94%|█████████▍| 18123/19208 [01:42<00:05, 190.51it/s]
#
# Selecting Coreset Indices.:  94%|█████████▍| 18143/19208 [01:42<00:05, 189.29it/s]
#
# Selecting Coreset Indices.:  95%|█████████▍| 18163/19208 [01:42<00:05, 189.97it/s]
#
# Selecting Coreset Indices.:  95%|█████████▍| 18183/19208 [01:42<00:05, 190.02it/s]
#
# Selecting Coreset Indices.:  95%|█████████▍| 18203/19208 [01:42<00:05, 190.28it/s]
#
# Selecting Coreset Indices.:  95%|█████████▍| 18223/19208 [01:42<00:05, 189.94it/s]
#
# Selecting Coreset Indices.:  95%|█████████▍| 18243/19208 [01:42<00:05, 190.43it/s]
#
# Selecting Coreset Indices.:  95%|█████████▌| 18263/19208 [01:43<00:04, 189.59it/s]
#
# Selecting Coreset Indices.:  95%|█████████▌| 18283/19208 [01:43<00:04, 190.46it/s]
#
# Selecting Coreset Indices.:  95%|█████████▌| 18303/19208 [01:43<00:04, 189.83it/s]
#
# Selecting Coreset Indices.:  95%|█████████▌| 18322/19208 [01:43<00:04, 189.06it/s]
#
#
# Selecting Coreset Indices.: 100%|█████████▉| 19151/19208 [01:47<00:00, 186.94it/s]
#
# Selecting Coreset Indices.: 100%|█████████▉| 19170/19208 [01:47<00:00, 187.79it/s]
#
# Selecting Coreset Indices.: 100%|██████████| 19208/19208 [01:48<00:00, 177.78it/s]
# INFO: `Trainer.fit` stopped: `max_epochs=1` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=1` reached.

# %%
results_PtCore = {}
predictions_PtCore = {}
for category in categories:
    # Perform inference
    predictions_PtCore[category] = engine_PtCore[category].predict(
        datamodule=dataset_PtCore[category],
        model=model_PtCore[category]
    )

    # Evaluate the model
    results_PtCore[category] = engine_PtCore[category].test(datamodule=dataset_PtCore[category], model=model_PtCore[category])
# Out:
# WARNING:anomalib.engine.engine:ckpt_path is not provided. Model weights will not be loaded.
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │    0.9877344369888306     │
# │       image_F1Score       │    0.9818181991577148     │
# │        pixel_AUROC        │    0.9476341009140015     │
# │       pixel_F1Score       │    0.6222663521766663     │
# └───────────────────────────┴───────────────────────────┘
# WARNING:anomalib.engine.engine:ckpt_path is not provided. Model weights will not be loaded.
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │    0.9782790541648865     │
# │       image_F1Score       │    0.9642857313156128     │
# │        pixel_AUROC        │    0.9793799519538879     │
# │       pixel_F1Score       │    0.3771977424621582     │
# └───────────────────────────┴───────────────────────────┘
# WARNING:anomalib.engine.engine:ckpt_path is not provided. Model weights will not be loaded.
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# WARNING:anomalib.metrics.f1_score:F1Score class exists for backwards compatibility. It will be removed in v1.1. Please use BinaryF1Score from torchmetrics instead
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        image_AUROC        │            1.0            │
# │       image_F1Score       │     0.994535505771637     │
# │        pixel_AUROC        │    0.9898858070373535     │
# │       pixel_F1Score       │    0.44103074073791504    │
# └───────────────────────────┴───────────────────────────┘

# %% [markdown]
# # *Results of Patchcore*

# %%
for category in categories:
  print(f"Category: {category}")
  print(f"Detection AUROC: {results_PtCore[category][0]['image_AUROC']}")
  print(f"Segmentation AUROC: {results_PtCore[category][0]['pixel_AUROC']}\n")
# Out:
# Category: tile
# Detection AUROC: 0.9877344369888306
# Segmentation AUROC: 0.9476341009140015
#
# Category: grid
# Detection AUROC: 0.9782790541648865
# Segmentation AUROC: 0.9793799519538879
#
# Category: leather
# Detection AUROC: 1.0
# Segmentation AUROC: 0.9898858070373535

# %%
total_auroc = 0
for category in categories:
  total_auroc += results_PtCore[category][0]['image_AUROC']  # Using image_AUROC
avg_auroc = total_auroc / len(categories)
print(f"Average AUROC across categories (Patchcore): {avg_auroc}")
# Out:
# Average AUROC across categories (Patchcore): 0.9886711637179056

# %%
# Get a sample image of tile
sample_anomaly_map_tile = predictions_PtCore['tile'][0]['anomaly_maps'][1].squeeze().cpu().numpy()
sample_image_tile = predictions_PtCore['tile'][0]['image'][1][1].numpy()
visualize_results(sample_image_tile, sample_anomaly_map_tile)

# %%
# Get a sample image of tile
sample_anomaly_map_leather = predictions_PtCore['leather'][0]['anomaly_maps'][1].squeeze().cpu().numpy()
sample_image_leather = predictions_PtCore['leather'][0]['image'][1][1].numpy()
visualize_results(sample_image_leather, sample_anomaly_map_leather)

# %%
# Get a sample image of tile
sample_anomaly_map_grid = predictions_PtCore['grid'][0]['anomaly_maps'][1].squeeze().cpu().numpy()
sample_image_grid = predictions_PtCore['grid'][0]['image'][1][1].numpy()
visualize_results(sample_image_grid, sample_anomaly_map_grid)

# %% [markdown]
# # *About Patchcore*
#
# Patchcore is an algorithm designed for detecting anomalies in images. It works by breaking down images into smaller patches and comparing each patch to a core set of normal patches.
#
# The Patchcore model analyzed the image of tile, grid and leather.
# The anomaly map reveals main areas of anomalies. The most significant hotspots have red spectrum on heatmap, corresponding to the normal image. This area shows high intensity in the anomaly map, suggesting potential anomaly.
#
# PatchCore extracts locally aware features from patches of normal images.
# It applies a subsampling technique (coreset*) to approximate these features and build a bank of patch features that describe normal patterns.
# At testing time, patch features are extracted for the test sample and anomaly scores are computed using a nearest-neighbor approach
#
# * **Coresets**: A coreset is a small, representative subset of the original dataset that can be used to approximate the solution to an optimization problem. This allows for significant reductions in computational complexity and memory requirements, making it easier to train models on large datasets.

# %% [markdown]
# # Differences between EfficientAd and Patchcore
#
# Industrial Application**(Important):
#
# Both are suitable for industrial applications, but EfficientAD's speed makes it particularly well-suited for high-speed, real-time inspection tasks.
#
# EfficientAd uses student-teacher approach to detect anomalies, which are able to detect both structural (local) and logical (global) anomalies. It makes it suitable for real-time applications.
#
# Patchcore is slower than EfficientAd as it uses coreset-subsampling. It is better suited for detecting fine-grained, localized anomalies.
#
#
# ---
#
#
# Approach:
#
# PatchCore - It uses a patch-based, memory bank approach. It breaks down images into smaller patches and compares them to a core set of normal patches.
#
# EfficientAD - It uses a combination of a student-teacher model for local anomalies and an autoencoder for logical anomalies.
#
#
# ---
#
#
# Architecture:
#
# PatchCore - It uses a pre-trained CNN (like ResNet) as a feature extractor, focusing on mid-level features.
#
# EfficientAD - It introduces a Patch Description Network (PDN) for local feature extraction and includes an autoencoder network.
#
#
#
# ---
#
#
#
# Training:
#
# PatchCore - It doesn't require fine-tuning of the feature extractor. It creates a memory bank of normal patch features.
#
# EfficientAD - It involves training both the student-teacher model and the autoencoder.
#
#
#
# ---
#
#
# Anomaly Detection Method:
#
# PatchCore - It uses a nearest-neighbor approach to detect anomalies, comparing test patches to the memory bank.
#
# EfficientAD - It combines local anomaly detection (using the student-teacher model) with logical anomaly detection (using the autoencoder).
#
#
#
# ---
#
#
#
# Speed:
#
# EfficientAD is noted for its extremely fast processing speed, capable of handling up to 600 images per second.
#
# PatchCore, while efficient, may not be as fast as EfficientAD due to its nearest-neighbor computations.

# %% [markdown]
# # Similarity Search

# %%
from qdrant_client import QdrantClient, models
from qdrant_client.http import models as rest
import numpy as np
import torch

# %%
client = QdrantClient(":memory:") # Connect to in-memory Qdrant instance

# %% [markdown]
# #### *For EfficientAd*

# %%
client.recreate_collection(
    collection_name="anomaly_maps_features",
    vectors_config=models.VectorParams(
        size=predictions_EfAd['tile'][0]['anomaly_maps'][0].flatten().shape[0],  # Adjust size
        distance=rest.Distance.COSINE
    ),
)
# Out:
# <ipython-input-110-790b729ccf02>:1: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# True

# %%
# Function to extract and flatten anomaly maps
def extract_anomaly_map_features(predictions, category, index):
    anomaly_map = predictions[category][0]['anomaly_maps'][index].cpu().numpy()
    return anomaly_map.flatten()

# %%
import uuid

all_points = []  # List to store all points
for category in categories:
    for i in range(len(predictions_EfAd[category][0]['anomaly_maps'])):
        features = extract_anomaly_map_features(predictions_EfAd, category, i)
        unique_id = str(uuid.uuid4())
        point = models.PointStruct(
            id=unique_id,
            vector=features.tolist(),
            payload={"category": category, "index": i}
        )
        all_points.append(point)

# Upsert all points at once
client.upsert(
    collection_name="anomaly_maps_features",
    points=all_points,
)
# Out:
# UpdateResult(operation_id=0, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
# Function to perform similarity search and visualize results
def similarity_search(query_anomaly_map, predictions, top_k=5):
    query_features = query_anomaly_map.flatten()
    search_result = client.search(
        collection_name="anomaly_maps_features",
        query_vector=query_features.tolist(),
        limit=top_k
    )

    return search_result

# %%
category = 'grid'
index = 0
sample_anomaly_map = predictions_EfAd[category][0]['anomaly_maps'][index].squeeze().cpu().numpy()
search_results = similarity_search(sample_anomaly_map, predictions_EfAd)

print("Query Image:")
visualize_results(predictions_EfAd[category][0]['image'][0][index].numpy(), sample_anomaly_map)

print(f"\nTop 5 Similar Anomalies:")
for result in search_results:
  category = result.payload.get("category")
  i = result.payload.get("index")

  # Retrieve the original image and anomaly map using category and index
  original_image = predictions_EfAd[category][0]['image'][i][index].numpy()
  retrieved_anomaly_map = predictions_EfAd[category][0]['anomaly_maps'][0].cpu().numpy()

  # Visualize the retrieved image and anomaly map separately
  plt.figure(figsize=(6, 4))
  plt.imshow(np.squeeze(original_image), cmap='grey')
  plt.title(f"Similar Image (ID: {result.id})")
  plt.axis('on')
  plt.show()

  print(f"ID: {result.id}, Score: {result.score}, Payload: {result.payload}\n")
# Out:
# Query Image:
# Top 5 Similar Anomalies:
# ID: ec680785-4c38-411c-9c47-5cd85cca2e45, Score: 0.9999999998851022, Payload: {'category': 'grid', 'index': 0}
# ID: 023d313a-3bed-4253-aa42-0676e257b061, Score: 0.9955063111052465, Payload: {'category': 'grid', 'index': 9}
# ID: 9ce97306-c3aa-4434-aa1e-84ee5b415aea, Score: 0.9946096837524808, Payload: {'category': 'grid', 'index': 26}
# ID: 4c038e8f-23e8-469a-8ade-a0cf88eec2eb, Score: 0.9941875618832303, Payload: {'category': 'grid', 'index': 24}
# ID: 3e7ce4d9-0f35-45f1-8747-c0fc67b642b9, Score: 0.9940572006407385, Payload: {'category': 'grid', 'index': 14}

# %% [markdown]
# ### *For Patchcore*

# %%
client.recreate_collection(
    collection_name="anomaly_maps_features",
    vectors_config=models.VectorParams(
        size=predictions_PtCore['tile'][0]['anomaly_maps'][0].flatten().shape[0],  # Adjust size
        distance=rest.Distance.COSINE
    ),
)
# Out:
# <ipython-input-118-ec618f79ae7e>:1: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# True

# %%
# Function to extract and flatten anomaly maps
def extract_anomaly_map_features(predictions, category, index):
    anomaly_map = predictions[category][0]['anomaly_maps'][index].cpu().numpy()
    return anomaly_map.flatten()

# %%
import uuid

all_points = []  # List to store all points
for category in categories:
    for i in range(len(predictions_PtCore[category][0]['anomaly_maps'])):
        features = extract_anomaly_map_features(predictions_PtCore, category, i)
        unique_id = str(uuid.uuid4())
        point = models.PointStruct(
            id=unique_id,
            vector=features.tolist(),
            payload={"category": category, "index": i}
        )
        all_points.append(point)

# Upsert all points at once
client.upsert(
    collection_name="anomaly_maps_features",
    points=all_points,
)
# Out:
# UpdateResult(operation_id=0, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
# Function to perform similarity search and visualize results
def similarity_search(query_anomaly_map, predictions, top_k=5):
    query_features = query_anomaly_map.flatten()
    search_result = client.search(
        collection_name="anomaly_maps_features",
        query_vector=query_features.tolist(),
        limit=top_k
    )

    return search_result

# %%
category = 'leather'
index = 0
sample_anomaly_map = predictions_PtCore[category][0]['anomaly_maps'][index].squeeze().cpu().numpy()
search_results = similarity_search(sample_anomaly_map, predictions_PtCore)

print("Query Image:")
visualize_results(predictions_PtCore[category][0]['image'][0][index].numpy(), sample_anomaly_map)

print(f"\nTop 5 Similar Anomalies:")
for result in search_results:
  category = result.payload.get('category')
  i = result.payload.get('index')

  # Retrieve the original image and anomaly map using category and index
  original_image = predictions_PtCore[category][0]['image'][i][index].numpy()
  retrieved_anomaly_map = predictions_PtCore[category][0]['anomaly_maps'][0].cpu().numpy()

  # Visualize the retrieved image and anomaly map separately
  plt.figure(figsize=(6, 4))
  plt.imshow(np.squeeze(original_image), cmap='grey')
  plt.title(f"Similar Image (ID: {result.id})")
  plt.axis('on')
  plt.show()

  print(f"ID: {result.id}, Score: {result.score}, Payload: {result.payload}\n")
# Out:
# Query Image:
# Top 5 Similar Anomalies:
# ID: 92f9cac2-bf27-455a-9e8c-b5c7859be11f, Score: 1.0000000880295876, Payload: {'category': 'leather', 'index': 0}
# ID: ea1f5c25-e661-4c61-8ce6-71331232322c, Score: 0.9519248088822032, Payload: {'category': 'leather', 'index': 8}
# ID: 73e53593-3b81-488c-8095-7d04b124d430, Score: 0.947419695707213, Payload: {'category': 'leather', 'index': 27}
# ID: d97df12b-f77a-4506-9e27-9dcd315ce364, Score: 0.9282036343639394, Payload: {'category': 'leather', 'index': 26}
# ID: 326da1d2-f42f-4997-8160-4cf9843cffc4, Score: 0.9021992736605775, Payload: {'category': 'leather', 'index': 12}

# %% [markdown]
# ### About Similarity Search
#
# Similarity search aims to find items within a dataset that are most similar to a given query item. This is based on a notion of "similarity" which is often defined using a distance metric (in this case it is COSINE).
#
# Feature Extraction: Anomaly maps generated by EfficientAd and Patchcore are converted into feature vectors by flattening the anomaly map array. These vectors capture the spatial distribution of anomalies.
#
# Vector Database: Qdrant is used to store these feature vectors along with metadata about the original images (category, index). Qdrant provides efficient indexing for fast similarity search.
#
# Querying: When a new anomaly map is generated, it's also converted into a feature vector and used as a query against the Qdrant database.
#
# Retrieval: Qdrant returns the most similar anomaly map vectors (and their associated image metadata) based on cosine similarity.
#
# Visualization: The retrieved images are displayed, allowing you to see visually similar anomaly patterns.
